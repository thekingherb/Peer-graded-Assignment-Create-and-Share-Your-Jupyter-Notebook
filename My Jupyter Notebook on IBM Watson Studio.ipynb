# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b>Hayden Hebert</b>
# Data Scienctiet

# %% [markdown]
# *I am interested in data science because of A.I.*

# %% [markdown]
# ### Addition of 1 and 1: outputs sum when run

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# * Eggs
# * Milk
# * Tacos

# %% [markdown]
# | header | header |
# | ------ | ------ |
# | cell | cell |

# %% [markdown]
# ![image of a cat sitting on a chair](https://content.instructables.com/FUI/NWTN/JVR5ZC1Y/FUINWTNJVR5ZC1Y.jpg?auto=webp)
